# %% [markdown]
# ## Introduction to Data Science I : Pandas Introduction

# %% [markdown]
# **Exercise #3 : Pandas Intro **
# Open the good_recs.csv file and load it into a Pandas DataFrame (let the index by default)

# %%
import csv, os
import pandas as pd

# %%
df = pd.read_csv('datasets\\good_recs.csv', skiprows=0, header=0)

# %%
#df
#df['exam_1'].count()
#df.count()

# %%
#1.1 Make a copy of the DataFrame and call it df_copy (we will use the copy for all exercises)
df_copy = df.copy()

# %%
#1.2 Find all records where ‘exam_2’ <= 60.0
df_copy[df_copy['exam_2'].le(60.0)]
# Out:
#     first_name  last_name                   company_name  \
# 1       Kendra       Loud              Deloitte & Touche
# 7       Josefa      Opitz              Norman Gale Isuzu
# 8          Lea  Steinhaus         James, Christopher Esq
# 17      Gianna     Branin   All Brevard Cert Apprsls Inc
# 24      Corrie    Kardell            Lynch, Steven J Esq
# ..         ...        ...                            ...
# 476     Gussie   Diflorio  Cliff Clarks Inc Sales & Serv
# 489   Maricela     Conger      Phase One Office Products
# 492     Dorsey    Neitzke               Turley, Joseph M
# 496  Kassandra   Marushia       Phelps Tool & Die Co Inc
# 499    Antonio      Unruh     Mission Lincoln Properties
#
#                   address            city province   postal        phone1  \
# 1         6 Arch St #9757          Alcida       NB  E8J 2C4  506-363-1526
# 7      136 W Grand Ave #3           Delhi       ON  N4B 1C4  519-788-7645
# ...

# %%
#1.3 List the indexes for the records in question #1.2
df_copy[df_copy['exam_2'].le(60.00)].index
# Out:
# Index([  1,   7,   8,  17,  24,  26,  38,  43,  44,  50,
#        ...
#        460, 464, 466, 474, 475, 476, 489, 492, 496, 499],
#       dtype='int64', length=119)

# %%
#1.4 Find all records where ‘exam_1’ and ‘exam_2’ are >= 65.0
#apply boolean mask to dataframe
filter = (df_copy['exam_1']>=65.0) & (df_copy['exam_2']>=65.0)
df_copy[filter]
#df_copy[(df_copy.exam_1 >=65.0) & (df_copy.exam_2 >=65.0)]
# Out:
#     first_name    last_name                    company_name  \
# 2      Lourdes     Bauswell               Oklahoma Neon Inc
# 3       Hannah      Edmison              M B A Paint Stores
# 4          Tom        Loeza       Sheraton Shreveport Hotel
# 10   Hortencia      Bresser     Batavia Chamber Of Commerce
# 13        Huey     Marcille  Southern Idaho Pipe & Stl Corp
# ..         ...          ...                             ...
# 487     Annice      Peckens             Hering, Glenn Z Esq
# 488      Effie      Frymark          Razzoog, Michael E Dds
# 490    Esteban  Plantenberg         Midwest Wheel Companies
# 491    Doretha        Wykle            Lafave, E Joseph Iii
# 498     Daniel       Dobler  Cosgroves N End Plbg & Hdwr Co
#
#                      address           city province   postal        phone1  \
# 2        9547 Belmont Rd #21     Belleville       ON  K8P 1B3  613-903-7043
# 3     73 Pittsford Victor Rd      Vancouver       BC  V5Z 3K2  604-334-3686
# ...

# %%
#1.5 List the indexes for the records in q. 1.4
df_copy[filter].index
# Out:
# Index([  2,   3,   4,  10,  13,  14,  19,  20,  22,  25,
#        ...
#        481, 482, 484, 485, 486, 487, 488, 490, 491, 498],
#       dtype='int64', length=238)

# %%
#1.6 Find all the records where ‘exam_1’ is NaN (null)
df_copy[df_copy['exam_1'].isnull()]
# Out:
#     first_name last_name                  company_name  \
# 15     Chandra     Lagos     Meredith Realty Group Inc
# 24      Corrie   Kardell           Lynch, Steven J Esq
# 54      Willis     Wylie        Acquired Knowledge Inc
# 163     Yasuko   Greeves                         Plant
# 324       Shay   Knieper                 Raby, Paul Ed
# 332    Lindsey   Arnoldi  Western States Petroleum Inc
# 345      Noble    Miyata              Auto Trim Design
# 454     Kelvin     Hasha  Orourke, Denise Michelle Esq
#
#                       address           city province   postal        phone1  \
# 15                7 N Dean St      Etobicoke       ON  M8Z 3P6  416-716-6446
# 24         75 Westchester Ave    Pierrefonds       QC  H9J 1W6  514-203-7817
# 54                 646 9th St  Saint-Raymond       QC  G3L 3X9  418-833-1949
# 163            4634 Anania Dr         Vernon       BC  V1B 3Z4  250-891-6910
# 324          571 Maiden Ln #7       Brossard       QC  J4X 1J9  450-806-3050
# ...

# %%
#1.7 List the indexes for records in q. 1.6
df_copy[df_copy['exam_1'].isnull()].index
# Out:
# Index([15, 24, 54, 163, 324, 332, 345, 454], dtype='int64')

# %%
#1.8 Find all records where both ‘exam_1’ and ‘exam_2’ are null. 
filter = df_copy['exam_1'].isnull() & df_copy['exam_2'].isnull()
df_copy[filter]
# Out:
#     first_name last_name      company_name                   address  \
# 345      Noble    Miyata  Auto Trim Design  7059 E Kilbourn Ave #252
#
#             city province   postal        phone1                   email  \
# 345  Tillsonburg       ON  N4G 4Y4  519-346-6651  noble_miyata@gmail.com
#
#                                web  exam_1  exam_2  exam_3 Dept transcode
# 345  http://www.autotrimdesign.com     NaN     NaN    53.0  BIO   Code095

# %%
#1.9 Drop records where ‘exam_3’ is null
df_copy.dropna(subset = ['exam_3'],inplace=False)
# Out:
#     first_name      last_name                    company_name  \
# 0    Francoise  Rautenstrauch               Riebesell, H F Jr
# 1       Kendra           Loud               Deloitte & Touche
# 2      Lourdes       Bauswell               Oklahoma Neon Inc
# 3       Hannah        Edmison              M B A Paint Stores
# 4          Tom          Loeza       Sheraton Shreveport Hotel
# ..         ...            ...                             ...
# 495       Erin      Delbosque             Curtiss Wright Corp
# 496  Kassandra       Marushia        Phelps Tool & Die Co Inc
# 497     Leslee        Matsuno         Factory Mattress Outlet
# 498     Daniel         Dobler  Cosgroves N End Plbg & Hdwr Co
# 499    Antonio          Unruh      Mission Lincoln Properties
#
#                     address            city province   postal        phone1  \
# 0        2335 Canton Hwy #6         Windsor       ON  N8N 3N2  519-569-8399
# ...

# %%
#1.10 Change the value of NaN (nulls) to 49.0
df_copy.fillna(value = 49.0, inplace=False).head(11)
# Out:
#    first_name      last_name                 company_name  \
# 0   Francoise  Rautenstrauch            Riebesell, H F Jr
# 1      Kendra           Loud            Deloitte & Touche
# 2     Lourdes       Bauswell            Oklahoma Neon Inc
# 3      Hannah        Edmison           M B A Paint Stores
# 4         Tom          Loeza    Sheraton Shreveport Hotel
# 5     Queenie     Kramarczyk     Goeman Wood Products Inc
# 6         Hui        Portaro  A Storage Inn Of Gloucester
# 7      Josefa          Opitz            Norman Gale Isuzu
# 8         Lea      Steinhaus       James, Christopher Esq
# 9       Paola         Vielma               Congress Title
# 10  Hortencia        Bresser  Batavia Chamber Of Commerce
#
#                     address           city province   postal        phone1  \
# 0        2335 Canton Hwy #6        Windsor       ON  N8N 3N2  519-569-8399
# 1           6 Arch St #9757         Alcida       NB  E8J 2C4  506-363-1526
# ...

# %%
#1.11 Drop the column ‘transcode’
df_copy.drop('transcode', axis=1, inplace=False)
# Out:
#     first_name      last_name                    company_name  \
# 0    Francoise  Rautenstrauch               Riebesell, H F Jr
# 1       Kendra           Loud               Deloitte & Touche
# 2      Lourdes       Bauswell               Oklahoma Neon Inc
# 3       Hannah        Edmison              M B A Paint Stores
# 4          Tom          Loeza       Sheraton Shreveport Hotel
# ..         ...            ...                             ...
# 495       Erin      Delbosque             Curtiss Wright Corp
# 496  Kassandra       Marushia        Phelps Tool & Die Co Inc
# 497     Leslee        Matsuno         Factory Mattress Outlet
# 498     Daniel         Dobler  Cosgroves N End Plbg & Hdwr Co
# 499    Antonio          Unruh      Mission Lincoln Properties
#
#                     address            city province   postal        phone1  \
# 0        2335 Canton Hwy #6         Windsor       ON  N8N 3N2  519-569-8399
# ...

# %%
#1.12 Change the value of exam_1 to 100.0 for record 3 
df_copy.loc[2,'exam_1'] = 100.00
df_copy.head(5)
# Out:
#   first_name      last_name               company_name  \
# 0  Francoise  Rautenstrauch          Riebesell, H F Jr
# 1     Kendra           Loud          Deloitte & Touche
# 2    Lourdes       Bauswell          Oklahoma Neon Inc
# 3     Hannah        Edmison         M B A Paint Stores
# 4        Tom          Loeza  Sheraton Shreveport Hotel
#
#                   address         city province   postal        phone1  \
# 0      2335 Canton Hwy #6      Windsor       ON  N8N 3N2  519-569-8399
# 1         6 Arch St #9757       Alcida       NB  E8J 2C4  506-363-1526
# 2     9547 Belmont Rd #21   Belleville       ON  K8P 1B3  613-903-7043
# 3  73 Pittsford Victor Rd    Vancouver       BC  V5Z 3K2  604-334-3686
# 4    447 Commercial St Se  LIle-Perrot       QC  J7V 4T4  514-487-6096
#
#                                        email  \
# 0  francoise.rautenstrauch@rautenstrauch.com
# 1                            kloud@gmail.com
# 2                   lourdes_bauswell@aol.com
# ...

# %%
df_copy.head(10)
# Out:
#   first_name      last_name                 company_name  \
# 0  Francoise  Rautenstrauch            Riebesell, H F Jr
# 1     Kendra           Loud            Deloitte & Touche
# 2    Lourdes       Bauswell            Oklahoma Neon Inc
# 3     Hannah        Edmison           M B A Paint Stores
# 4        Tom          Loeza    Sheraton Shreveport Hotel
# 5    Queenie     Kramarczyk     Goeman Wood Products Inc
# 6        Hui        Portaro  A Storage Inn Of Gloucester
# 7     Josefa          Opitz            Norman Gale Isuzu
# 8        Lea      Steinhaus       James, Christopher Esq
# 9      Paola         Vielma               Congress Title
#
#                   address           city province   postal        phone1  \
# 0      2335 Canton Hwy #6        Windsor       ON  N8N 3N2  519-569-8399
# 1         6 Arch St #9757         Alcida       NB  E8J 2C4  506-363-1526
# 2     9547 Belmont Rd #21     Belleville       ON  K8P 1B3  613-903-7043
# ...

# %%
#1.13 Substract 2 from every exam_2 value
df_copy['exam_2'] = df_copy['exam_2'] - 2
df_copy.head(10)
# Out:
#   first_name      last_name                 company_name  \
# 0  Francoise  Rautenstrauch            Riebesell, H F Jr
# 1     Kendra           Loud            Deloitte & Touche
# 2    Lourdes       Bauswell            Oklahoma Neon Inc
# 3     Hannah        Edmison           M B A Paint Stores
# 4        Tom          Loeza    Sheraton Shreveport Hotel
# 5    Queenie     Kramarczyk     Goeman Wood Products Inc
# 6        Hui        Portaro  A Storage Inn Of Gloucester
# 7     Josefa          Opitz            Norman Gale Isuzu
# 8        Lea      Steinhaus       James, Christopher Esq
# 9      Paola         Vielma               Congress Title
#
#                   address           city province   postal        phone1  \
# 0      2335 Canton Hwy #6        Windsor       ON  N8N 3N2  519-569-8399
# 1         6 Arch St #9757         Alcida       NB  E8J 2C4  506-363-1526
# 2     9547 Belmont Rd #21     Belleville       ON  K8P 1B3  613-903-7043
# ...

# %%
#1.14 Add a new column ‘AVG’ with mean of all 3 exams.
df_copy['AVG'] = df_copy[['exam_1', 'exam_2', 'exam_3']].mean(axis=1).round(2)

# %%
df_copy.head(10)
# Out:
#   first_name      last_name                 company_name  \
# 0  Francoise  Rautenstrauch            Riebesell, H F Jr
# 1     Kendra           Loud            Deloitte & Touche
# 2    Lourdes       Bauswell            Oklahoma Neon Inc
# 3     Hannah        Edmison           M B A Paint Stores
# 4        Tom          Loeza    Sheraton Shreveport Hotel
# 5    Queenie     Kramarczyk     Goeman Wood Products Inc
# 6        Hui        Portaro  A Storage Inn Of Gloucester
# 7     Josefa          Opitz            Norman Gale Isuzu
# 8        Lea      Steinhaus       James, Christopher Esq
# 9      Paola         Vielma               Congress Title
#
#                   address           city province   postal        phone1  \
# 0      2335 Canton Hwy #6        Windsor       ON  N8N 3N2  519-569-8399
# 1         6 Arch St #9757         Alcida       NB  E8J 2C4  506-363-1526
# 2     9547 Belmont Rd #21     Belleville       ON  K8P 1B3  613-903-7043
# ...

# %%
#1.15 What is the Max and Min values for exam_2

print('Minimum value for exam_2:' , df['exam_2'].min())
print('Maximum value for exam_2:' , df['exam_2'].max())
# Out:
# Minimum value for exam_2: 50.0
# Maximum value for exam_2: 100.0

# %%
#1.16 What is the Standard Deviation for exam_1, exam_2 and exam_3 (separately)

print('Standard deviation for exam_1:' , "{:.2f}".format(df['exam_1'].std()))
print('Standard deviation for exam_2:' , "{:.2f}".format(df['exam_2'].std()))
print('Standard deviation for exam_3:' , "{:.2f}".format(df['exam_3'].std()))
# Out:
# Standard deviation for exam_1: 15.19
# Standard deviation for exam_2: 14.99
# Standard deviation for exam_3: 14.86

# %%
#1.17 Group records by ‘Dept’ and show the mean for exam_1, exam_2 and exam_3
dept_group = df_copy.groupby('Dept')
dept_group[['exam_1','exam_2', 'exam_3']].mean().round(2)
# Out:
#       exam_1  exam_2  exam_3
# Dept
# BIO    74.30   74.36   75.55
# MATH   74.61   72.16   73.44
# PHY    76.76   70.96   74.17
# POL    75.59   72.23   71.71

# %%
#Filter through dataframe  
df_copy.sort_values(by='Dept', ascending=True)
filter = df_copy['last_name'].str.contains('Lo',regex=False)
df_copy[filter]
# Out:
#     first_name last_name                  company_name  \
# 1       Kendra      Loud             Deloitte & Touche
# 4          Tom     Loeza     Sheraton Shreveport Hotel
# 64       Jaime  Lowrance            Sams Liquor & Deli
# 116     Stacey     Lortz  Electrical Workers Unon Ibew
# 184  Broderick    Lorenz       Frascella, Thomas P Esq
# 197     Rodney   Lockamy          Schultz, Barry J Esq
# 289   Anjelica    Lovero     Dayton Appliance Parts Co
# 310   Dorothea   Lowther              Herline, Georgia
# 334     Nobuko   Logwood                       Ads Inc
#
#                            address         city province   postal  \
# 1                  6 Arch St #9757       Alcida       NB  E8J 2C4
# 4             447 Commercial St Se  LIle-Perrot       QC  J7V 4T4
# 64                   1 Nw 167th St     Winnipeg       MB  R3J 2Z1
# 116                 5039 Coffee Rd  Scarborough       ON  M1K 1H4
# 184                   185 Davis St    Saskatoon       SK  S7N 3M6
# ...
